# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
#  **Answer:** We can reuse the code and readability also increases if we have fuctions in our code
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
#  **Answer:** the code in a function run only when it is called not when it's specified
#
#
# 3. What statement creates a function?
#
#  **Answer:** def is the keyword we use to define a function
#
#
# 4. What is the difference between a function and a function call?
#
#  **Answer:** function is a lines of code where function call executes those lines of code inside a function
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
#  **Answer:** There is only one global scope in python program and local scope is within the indentation
#
#
# 6. What happens to variables in a local scope when the function call returns?
#
#  **Answer:** when function call returns the local variable will be no longer available.
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
#  **Answer:** Return value is the value that the function returns to the caller of the function, Yes we can return the value in an expression for example return a+b when we want addition of the two variable passed to the function
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
#  **Answer:** it will return nonetype
#
#
# 9. How do you make a function variable refer to the global variable?
#
#  **Answer:** By using the **global** keyword
#
# 10. What is the data type of None?
#
#  **Answer:**: nonetype
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
#  **Answer:** **import** statement imports the **areallyourpetsnamederic** module
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
#  **Answer:** spam.bacon()
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
#  **Answer:** exception handling writing try catch block
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
#  **Answer:** try and except clause are part of exception handling when we know some part of the program might fail during execution we write such code under **try clause** and **except clause** catches the error cause inside try clause and lets the program run without completely halting the program.
